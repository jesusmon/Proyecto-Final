# %% [markdown]
# <a href="https://colab.research.google.com/github/jesusmon/Proyecto-Final/blob/main/Clase_del_viernes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Contraseña = input("Escribe tu nombre para poder contestar tu cuestionario: ")
if Contraseña == "Jesus":
 print("Contesta lo siguiente")
if Contraseña != "Jesus":
  print("Este no es tu nombre")

print("Lee el sigueinte instructivo: ")
print("Redacta la siguiente palabra tal cuál está:")
Palabracorrecta = input("P4t4mb0")
if Palabracorrecta == "P4t4mb0":
  print("Acceso concedido")
if Palabracorrecta != "P4t4mb0":
  print("Acceso denegado")
# Out:
# Escribe tu nombre para poder contestar tu cuestionario: Jesus
# Contesta lo siguiente
# Lee el sigueinte instructivo:
# Redacta la siguiente palabra tal cuál está:
# P4t4mb0P4t4mb0
# Acceso concedido

# %%
import pandas as pd
x = 10
pandas.read_csv(filepath_or_buffer="/content/sample_data/Clse viernes.csv")
# Out:
#          Marca temporal                 Dirección de correo electrónico  \
# 0   18/08/2023 19:00:54                  jesusmontufar@ciencias.unam.mx
# 1   18/08/2023 19:05:31                  jesusmontufar@ciencias.unam.mx
# 2   18/08/2023 19:14:12                     emmanuel21@ciencias.unam.mx
# 3   18/08/2023 22:18:32  brayanaxel.villalpandoestrada@ciencias.unam.mx
# 4   19/08/2023 11:37:38         ximena.castillo.pineda@ciencias.unam.mx
# 5   21/08/2023 21:40:36                       06robles@ciencias.unam.mx
# 6   21/08/2023 21:52:30                   ivonne.delacruz1313@gmail.com
# 7    22/08/2023 8:06:40              contacto_maurilio@ciencias.unam.mx
# 8   24/08/2023 12:23:53                         raguer@ciencias.unam.mx
# 9   24/08/2023 12:30:35                            giebelemtz@gmail.com
# 10  24/08/2023 12:31:52                        sofiasepulveda@gmail.com
# 11  24/08/2023 12:44:57                               vanessa@gmail.com
#
# ...

# %%
import pandas as pd
x = 10
TABLA = pandas.read_csv("/content/sample_data/Clse viernes.csv")
